# %% [markdown]
# <a href="https://colab.research.google.com/github/NurFaizin/ann-backpropagation/blob/main/ann_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from csv import reader
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# Load a CSV file
def load_csv(filename, skip_header=True):
    dataset = list()
    with open(filename, 'r') as file:
        csv_reader = reader(file)
        if skip_header:
            next(csv_reader, None)
        for row in csv_reader:
            if not row:
                continue
            dataset.append(row)
    return np.array(dataset)

# %%
# ReLU activation function
def relu(z):
    a = np.maximum(0,z)
    return a

# %%
# Sigmoid activation function
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
# Network initializations
def init_network(layer_sizes):
    network = {}
    for i in range(1, len(layer_sizes)):
        network['W' + str(i)] = np.random.randn(layer_sizes[i], layer_sizes[i-1])*0.01
        network['B' + str(i)] = np.random.randn(layer_sizes[i],1)*0.01
    return network

# %%
# Feed forward
def forward_propagation(X_train, params):
    layers = len(params)//2
    values = {}
    for i in range(1, layers+1):
        if i==1:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], X_train) + params['B' + str(i)]
            values['A' + str(i)] = sigmoid(values['Z' + str(i)])
        else:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], values['A' + str(i-1)]) + params['B' + str(i)]
            if i==layers:
                values['A' + str(i)] = values['Z' + str(i)]
            else:
                values['A' + str(i)] = sigmoid(values['Z' + str(i)])
    return values

# %%
# Compute the error
def compute_error(values, Y_train):
    layers = len(values)//2
    Y_pred = values['A' + str(layers)]
    error = 1/(2*len(Y_train)) * np.sum(np.square(Y_pred - Y_train))
    return error

# %%
# Back propagation
def backward_propagation(params, values, X_train, Y_train):
    layers = len(params)//2
    m = len(Y_train)
    grads = {}
    for i in range(layers,0,-1):
        if i==layers:
            dA = 1/m * (values['A' + str(i)] - Y_train)
            dZ = dA
        else:
            dA = np.dot(params['W' + str(i+1)].T, dZ)
            dZ = np.multiply(dA, np.where(values['A' + str(i)]>=0, 1, 0))
        if i==1:
            grads['W' + str(i)] = 1/m * np.dot(dZ, X_train.T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
        else:
            grads['W' + str(i)] = 1/m * np.dot(dZ,values['A' + str(i-1)].T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
    return grads

# %%
# Update parameters
def update_params(params, grads, learning_rate):
    layers = len(params)//2
    params_updated = {}
    for i in range(1,layers+1):
        params_updated['W' + str(i)] = params['W' + str(i)] - learning_rate * grads['W' + str(i)]
        params_updated['B' + str(i)] = params['B' + str(i)] - learning_rate * grads['B' + str(i)]
    return params_updated

# %%
# Train model
def train(X_train, Y_train, layer_sizes, num_iters, learning_rate):
    params = init_network(layer_sizes)
    for i in range(num_iters):
        values = forward_propagation(X_train.T, params)
        cost = compute_error(values, Y_train.T)
        grads = backward_propagation(params, values,X_train.T, Y_train.T)
        params = update_params(params, grads, learning_rate)
        print('Error at epoch ' + str(i+1) + ' = ' + str(cost) + '\n')
    return params

# %%
# Compute the acccuracy
def compute_accuracy(X_train, X_test, Y_train, Y_test, params):
    values_train = forward_propagation(X_train.T, params)
    values_test = forward_propagation(X_test.T, params)
    train_acc = mean_squared_error(Y_train, values_train['A' + str(len(layer_sizes)-1)].T)
    test_acc = mean_squared_error(Y_test, values_test['A' + str(len(layer_sizes)-1)].T)
    return train_acc, test_acc

# %%
# Predict
def predict(X, params):
    values = forward_propagation(X.T, params)
    predictions = values['A' + str(len(values)//2)].T
    return predictions

# %%
data = load_csv('/content/drive/MyDrive/Colab Notebooks/diabetes.csv')            #load dataset
X = data[:, 0:8].astype('float')                                                  #get input columns
Y = data[:, 8].astype('int')                                                      #get target column
X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size = 0.2)           #split data into train and test sets in 80-20 ratio

# %%
layer_sizes = [8, 5, 1]                                                       #set layer sizes, do not change the size of the first and last layer 
num_iters = 1000                                                                    #set number of iterations over the training set(also known as epochs in batch gradient descent context)
learning_rate = 0.05                                                              #set learning rate for gradient descent

# %%
model = train(X_train, Y_train, layer_sizes, num_iters, learning_rate)           #train the model
train_acc, test_acc = compute_accuracy(X_train, X_test, Y_train, Y_test, model)  #get training and test accuracy
# Out:
# Cost at iteration 1 = 0.17878508173539429
#
# Cost at iteration 2 = 0.17876922027943637
#
# Cost at iteration 3 = 0.17875336270974534
#
# Cost at iteration 4 = 0.17873750902536042
#
# Cost at iteration 5 = 0.17872165922532096
#
# Cost at iteration 6 = 0.17870581330866664
#
# Cost at iteration 7 = 0.17868997127443734
#
# Cost at iteration 8 = 0.17867413312167324
#
# Cost at iteration 9 = 0.1786582988494147
#
# Cost at iteration 10 = 0.17864246845670237
#
# Cost at iteration 11 = 0.17862664194257716
#
# Cost at iteration 12 = 0.1786108193060801
#
# Cost at iteration 13 = 0.17859500054625263
#
# Cost at iteration 14 = 0.17857918566213637
#
# Cost at iteration 15 = 0.1785633746527731
#
# Cost at iteration 16 = 0.17854756751720502
#
# Cost at iteration 17 = 0.1785317642544744
#
# Cost at iteration 18 = 0.17851596486362384
#
# Cost at iteration 19 = 0.17850016934369617
#
# Cost at iteration 20 = 0.17848437769373446
#
# Cost at iteration 21 = 0.17846858991278208
#
# Cost at iteration 22 = 0.17845280599988247
#
# Cost at iteration 23 = 0.1784370259540796
#
# Cost at iteration 24 = 0.17842124977441737
#
# Cost at iteration 25 = 0.17840547745994012
#
# Cost at iteration 26 = 0.17838970900969242
#
# Cost at iteration 27 = 0.17837394442271895
#
# Cost at iteration 28 = 0.1783581836980649
#
# Cost at iteration 29 = 0.17834242683477536
#
# Cost at iteration 30 = 0.1783266738318959
#
# Cost at iteration 31 = 0.1783109246884723
#
# Cost at iteration 32 = 0.1782951794035505
#
# Cost at iteration 33 = 0.1782794379761768
#
# Cost at iteration 34 = 0.17826370040539757
#
# Cost at iteration 35 = 0.17824796669025966
#
# Cost at iteration 36 = 0.1782322368298099
#
# Cost at iteration 37 = 0.17821651082309561
#
# Cost at iteration 38 = 0.1782007886691642
#
# Cost at iteration 39 = 0.17818507036706333
#
# Cost at iteration 40 = 0.1781693559158409
#
# Cost at iteration 41 = 0.1781536453145452
#
# Cost at iteration 42 = 0.17813793856222454
#
# Cost at iteration 43 = 0.17812223565792767
#
# Cost at iteration 44 = 0.17810653660070339
#
# Cost at iteration 45 = 0.17809084138960088
#
# Cost at iteration 46 = 0.17807515002366955
#
# Cost at iteration 47 = 0.17805946250195903
#
# Cost at iteration 48 = 0.17804377882351916
#
# Cost at iteration 49 = 0.17802809898740002
#
# Cost at iteration 50 = 0.17801242299265202
#
# Cost at iteration 51 = 0.17799675083832575
#
# Cost at iteration 52 = 0.17798108252347197
#
# Cost at iteration 53 = 0.17796541804714183
#
# Cost at iteration 54 = 0.17794975740838667
#
# Cost at iteration 55 = 0.17793410060625797
#
# Cost at iteration 56 = 0.17791844763980755
#
# Cost at iteration 57 = 0.17790279850808746
#
# Cost at iteration 58 = 0.17788715321015
#
# Cost at iteration 59 = 0.17787151174504767
#
# Cost at iteration 60 = 0.17785587411183326
#
# Cost at iteration 61 = 0.17784024030955972
#
# Cost at iteration 62 = 0.17782461033728036
#
# Cost at iteration 63 = 0.17780898419404864
#
# Cost at iteration 64 = 0.17779336187891825
#
# Cost at iteration 65 = 0.1777777433909432
#
# Cost at iteration 66 = 0.17776212872917774
#
# Cost at iteration 67 = 0.17774651789267623
#
# Cost at iteration 68 = 0.17773091088049334
#
# Cost at iteration 69 = 0.17771530769168412
#
# Cost at iteration 70 = 0.17769970832530368
#
# Cost at iteration 71 = 0.1776841127804074
#
# Cost at iteration 72 = 0.17766852105605097
#
# Cost at iteration 73 = 0.17765293315129027
#
# Cost at iteration 74 = 0.17763734906518142
#
# Cost at iteration 75 = 0.1776217687967808
#
# Cost at iteration 76 = 0.177606192345145
#
# Cost at iteration 77 = 0.1775906197093309
#
# Cost at iteration 78 = 0.17757505088839556
#
# Cost at iteration 79 = 0.17755948588139633
#
# Cost at iteration 80 = 0.1775439246873908
#
# Cost at iteration 81 = 0.17752836730543675
#
# Cost at iteration 82 = 0.1775128137345922
#
# Cost at iteration 83 = 0.1774972639739155
#
# Cost at iteration 84 = 0.17748171802246512
#
# Cost at iteration 85 = 0.1774661758792999
#
# Cost at iteration 86 = 0.17745063754347878
#
# Cost at iteration 87 = 0.17743510301406104
#
# Cost at iteration 88 = 0.17741957229010613
#
# Cost at iteration 89 = 0.1774040453706738
#
# Cost at iteration 90 = 0.177388522254824
#
# Cost at iteration 91 = 0.17737300294161693
#
# Cost at iteration 92 = 0.17735748743011304
#
# Cost at iteration 93 = 0.17734197571937302
#
# Cost at iteration 94 = 0.1773264678084578
#
# Cost at iteration 95 = 0.17731096369642846
#
# Cost at iteration 96 = 0.17729546338234647
#
# Cost at iteration 97 = 0.17727996686527342
#
# Cost at iteration 98 = 0.17726447414427127
#
# Cost at iteration 99 = 0.177248985218402
#
# Cost at iteration 100 = 0.177233500086728
#
# Cost at iteration 101 = 0.17721801874831192
#
# Cost at iteration 102 = 0.1772025412022166
#
# Cost at iteration 103 = 0.17718706744750495
#
# Cost at iteration 104 = 0.17717159748324043
#
# Cost at iteration 105 = 0.17715613130848648
#
# Cost at iteration 106 = 0.17714066892230693
#
# Cost at iteration 107 = 0.1771252103237658
#
# Cost at iteration 108 = 0.1771097555119273
#
# Cost at iteration 109 = 0.17709430448585595
#
# Cost at iteration 110 = 0.1770788572446165
#
# Cost at iteration 111 = 0.1770634137872739
#
# Cost at iteration 112 = 0.17704797411289336
#
# Cost at iteration 113 = 0.1770325382205403
#
# Cost at iteration 114 = 0.17701710610928034
#
# Cost at iteration 115 = 0.17700167777817954
#
# Cost at iteration 116 = 0.17698625322630396
#
# Cost at iteration 117 = 0.17697083245272002
#
# Cost at iteration 118 = 0.1769554154564943
#
# Cost at iteration 119 = 0.17694000223669376
#
# Cost at iteration 120 = 0.17692459279238543
#
# Cost at iteration 121 = 0.17690918712263667
#
# Cost at iteration 122 = 0.17689378522651505
#
# Cost at iteration 123 = 0.1768783871030884
#
# Cost at iteration 124 = 0.17686299275142475
#
# Cost at iteration 125 = 0.17684760217059242
#
# Cost at iteration 126 = 0.17683221535965984
#
# Cost at iteration 127 = 0.17681683231769593
#
# Cost at iteration 128 = 0.17680145304376954
#
# Cost at iteration 129 = 0.17678607753694994
#
# Cost at iteration 130 = 0.1767707057963067
#
# Cost at iteration 131 = 0.17675533782090938
#
# Cost at iteration 132 = 0.17673997360982804
#
# Cost at iteration 133 = 0.17672461316213278
#
# Cost at iteration 134 = 0.17670925647689406
#
# Cost at iteration 135 = 0.17669390355318249
#
# Cost at iteration 136 = 0.176678554390069
#
# Cost at iteration 137 = 0.1766632089866247
#
# Cost at iteration 138 = 0.1766478673419209
#
# Cost at iteration 139 = 0.17663252945502927
#
# Cost at iteration 140 = 0.17661719532502163
#
# Cost at iteration 141 = 0.17660186495097
#
# Cost at iteration 142 = 0.17658653833194674
#
# Cost at iteration 143 = 0.17657121546702434
#
# Cost at iteration 144 = 0.17655589635527558
#
# Cost at iteration 145 = 0.1765405809957735
#
# Cost at iteration 146 = 0.1765252693875913
#
# Cost at iteration 147 = 0.17650996152980247
#
# Cost at iteration 148 = 0.17649465742148074
#
# Cost at iteration 149 = 0.17647935706170007
#
# Cost at iteration 150 = 0.17646406044953464
#
# Cost at iteration 151 = 0.17644876758405886
#
# Cost at iteration 152 = 0.1764334784643474
#
# Cost at iteration 153 = 0.17641819308947515
#
# Cost at iteration 154 = 0.17640291145851716
#
# Cost at iteration 155 = 0.1763876335705489
#
# Cost at iteration 156 = 0.17637235942464588
#
# Cost at iteration 157 = 0.176357089019884
#
# Cost at iteration 158 = 0.1763418223553393
#
# Cost at iteration 159 = 0.17632655943008801
#
# Cost at iteration 160 = 0.1763113002432068
#
# Cost at iteration 161 = 0.17629604479377234
#
# Cost at iteration 162 = 0.17628079308086161
#
# Cost at iteration 163 = 0.1762655451035519
#
# Cost at iteration 164 = 0.17625030086092067
#
# Cost at iteration 165 = 0.17623506035204567
#
# Cost at iteration 166 = 0.17621982357600474
#
# Cost at iteration 167 = 0.1762045905318761
#
# Cost at iteration 168 = 0.1761893612187382
#
# Cost at iteration 169 = 0.17617413563566964
#
# Cost at iteration 170 = 0.1761589137817493
#
# Cost at iteration 171 = 0.17614369565605628
#
# Cost at iteration 172 = 0.17612848125766992
#
# Cost at iteration 173 = 0.17611327058566978
#
# Cost at iteration 174 = 0.17609806363913574
#
# Cost at iteration 175 = 0.17608286041714777
#
# Cost at iteration 176 = 0.17606766091878617
#
# Cost at iteration 177 = 0.1760524651431315
#
# Cost at iteration 178 = 0.17603727308926442
#
# Cost at iteration 179 = 0.17602208475626596
#
# Cost at iteration 180 = 0.1760069001432173
#
# Cost at iteration 181 = 0.17599171924919993
#
# Cost at iteration 182 = 0.17597654207329544
#
# Cost at iteration 183 = 0.17596136861458583
#
# Cost at iteration 184 = 0.17594619887215324
#
# Cost at iteration 185 = 0.17593103284507997
#
# Cost at iteration 186 = 0.17591587053244864
#
# Cost at iteration 187 = 0.17590071193334214
#
# Cost at iteration 188 = 0.17588555704684358
#
# Cost at iteration 189 = 0.17587040587203617
#
# Cost at iteration 190 = 0.1758552584080035
#
# Cost at iteration 191 = 0.17584011465382932
#
# Cost at iteration 192 = 0.17582497460859764
#
# Cost at iteration 193 = 0.17580983827139274
#
# Cost at iteration 194 = 0.17579470564129904
#
# Cost at iteration 195 = 0.17577957671740124
#
# Cost at iteration 196 = 0.1757644514987843
#
# Cost at iteration 197 = 0.17574932998453333
#
# Cost at iteration 198 = 0.17573421217373383
#
# Cost at iteration 199 = 0.17571909806547137
#
# Cost at iteration 200 = 0.17570398765883175
#
# Cost at iteration 201 = 0.17568888095290114
#
# Cost at iteration 202 = 0.1756737779467659
#
# Cost at iteration 203 = 0.17565867863951248
#
# Cost at iteration 204 = 0.17564358303022778
#
# Cost at iteration 205 = 0.17562849111799872
#
# Cost at iteration 206 = 0.17561340290191266
#
# Cost at iteration 207 = 0.175598318381057
#
# Cost at iteration 208 = 0.17558323755451946
#
# Cost at iteration 209 = 0.17556816042138798
#
# Cost at iteration 210 = 0.17555308698075084
#
# Cost at iteration 211 = 0.17553801723169632
#
# Cost at iteration 212 = 0.1755229511733131
#
# Cost at iteration 213 = 0.17550788880469012
#
# Cost at iteration 214 = 0.1754928301249164
#
# Cost at iteration 215 = 0.17547777513308133
#
# Cost at iteration 216 = 0.1754627238282744
#
# Cost at iteration 217 = 0.17544767620958548
#
# Cost at iteration 218 = 0.1754326322761046
#
# Cost at iteration 219 = 0.17541759202692195
#
# Cost at iteration 220 = 0.17540255546112807
#
# Cost at iteration 221 = 0.17538752257781368
#
# Cost at iteration 222 = 0.17537249337606972
#
# Cost at iteration 223 = 0.17535746785498732
#
# Cost at iteration 224 = 0.17534244601365798
#
# Cost at iteration 225 = 0.17532742785117325
#
# Cost at iteration 226 = 0.1753124133666251
#
# Cost at iteration 227 = 0.17529740255910556
#
# Cost at iteration 228 = 0.175282395427707
#
# Cost at iteration 229 = 0.17526739197152194
#
# Cost at iteration 230 = 0.1752523921896432
#
# Cost at iteration 231 = 0.1752373960811638
#
# Cost at iteration 232 = 0.175222403645177
#
# Cost at iteration 233 = 0.17520741488077626
#
# Cost at iteration 234 = 0.17519242978705532
#
# Cost at iteration 235 = 0.17517744836310808
#
# Cost at iteration 236 = 0.1751624706080288
#
# Cost at iteration 237 = 0.17514749652091177
#
# Cost at iteration 238 = 0.17513252610085167
#
# Cost at iteration 239 = 0.17511755934694337
#
# Cost at iteration 240 = 0.17510259625828195
#
# Cost at iteration 241 = 0.17508763683396275
#
# Cost at iteration 242 = 0.17507268107308127
#
# Cost at iteration 243 = 0.17505772897473337
#
# Cost at iteration 244 = 0.17504278053801495
#
# Cost at iteration 245 = 0.17502783576202233
#
# Cost at iteration 246 = 0.1750128946458519
#
# Cost at iteration 247 = 0.17499795718860042
#
# Cost at iteration 248 = 0.17498302338936483
#
# Cost at iteration 249 = 0.17496809324724222
#
# Cost at iteration 250 = 0.17495316676133002
#
# Cost at iteration 251 = 0.1749382439307258
#
# Cost at iteration 252 = 0.1749233247545274
#
# Cost at iteration 253 = 0.17490840923183293
#
# Cost at iteration 254 = 0.17489349736174065
#
# Cost at iteration 255 = 0.1748785891433491
#
# Cost at iteration 256 = 0.17486368457575702
#
# Cost at iteration 257 = 0.17484878365806342
#
# Cost at iteration 258 = 0.17483388638936745
#
# Cost at iteration 259 = 0.1748189927687686
#
# Cost at iteration 260 = 0.1748041027953666
#
# Cost at iteration 261 = 0.1747892164682612
#
# Cost at iteration 262 = 0.1747743337865526
#
# Cost at iteration 263 = 0.17475945474934113
#
# Cost at iteration 264 = 0.1747445793557274
#
# Cost at iteration 265 = 0.1747297076048122
#
# Cost at iteration 266 = 0.17471483949569663
#
# Cost at iteration 267 = 0.1746999750274818
#
# Cost at iteration 268 = 0.17468511419926933
#
# Cost at iteration 269 = 0.17467025701016087
#
# Cost at iteration 270 = 0.17465540345925837
#
# Cost at iteration 271 = 0.17464055354566407
#
# Cost at iteration 272 = 0.1746257072684803
#
# Cost at iteration 273 = 0.17461086462680975
#
# Cost at iteration 274 = 0.1745960256197552
#
# Cost at iteration 275 = 0.17458119024641977
#
# Cost at iteration 276 = 0.17456635850590682
#
# Cost at iteration 277 = 0.17455153039731983
#
# Cost at iteration 278 = 0.17453670591976253
#
# Cost at iteration 279 = 0.17452188507233898
#
# Cost at iteration 280 = 0.1745070678541534
#
# Cost at iteration 281 = 0.1744922542643102
#
# Cost at iteration 282 = 0.17447744430191403
#
# Cost at iteration 283 = 0.17446263796606984
#
# Cost at iteration 284 = 0.17444783525588273
#
# Cost at iteration 285 = 0.17443303617045808
#
# Cost at iteration 286 = 0.17441824070890144
#
# Cost at iteration 287 = 0.17440344887031864
#
# Cost at iteration 288 = 0.17438866065381567
#
# Cost at iteration 289 = 0.17437387605849886
#
# Cost at iteration 290 = 0.1743590950834746
#
# Cost at iteration 291 = 0.17434431772784972
#
# Cost at iteration 292 = 0.17432954399073106
#
# Cost at iteration 293 = 0.17431477387122585
#
# Cost at iteration 294 = 0.17430000736844142
#
# Cost at iteration 295 = 0.1742852444814854
#
# Cost at iteration 296 = 0.17427048520946567
#
# Cost at iteration 297 = 0.1742557295514903
#
# Cost at iteration 298 = 0.17424097750666753
#
# Cost at iteration 299 = 0.1742262290741059
#
# Cost at iteration 300 = 0.1742114842529142
#
# Cost at iteration 301 = 0.17419674304220137
#
# Cost at iteration 302 = 0.1741820054410766
#
# Cost at iteration 303 = 0.1741672714486493
#
# Cost at iteration 304 = 0.17415254106402916
#
# Cost at iteration 305 = 0.17413781428632602
#
# Cost at iteration 306 = 0.17412309111465002
#
# Cost at iteration 307 = 0.17410837154811146
#
# Cost at iteration 308 = 0.17409365558582088
#
# Cost at iteration 309 = 0.17407894322688902
#
# Cost at iteration 310 = 0.174064234470427
#
# Cost at iteration 311 = 0.17404952931554593
#
# Cost at iteration 312 = 0.1740348277613573
#
# Cost at iteration 313 = 0.1740201298069728
#
# Cost at iteration 314 = 0.17400543545150432
#
# Cost at iteration 315 = 0.17399074469406398
#
# Cost at iteration 316 = 0.17397605753376416
#
# Cost at iteration 317 = 0.17396137396971736
#
# Cost at iteration 318 = 0.1739466940010365
#
# Cost at iteration 319 = 0.1739320176268345
#
# Cost at iteration 320 = 0.17391734484622462
#
# Cost at iteration 321 = 0.17390267565832038
#
# Cost at iteration 322 = 0.17388801006223548
#
# Cost at iteration 323 = 0.1738733480570838
#
# Cost at iteration 324 = 0.17385868964197954
#
# Cost at iteration 325 = 0.173844034816037
#
# Cost at iteration 326 = 0.17382938357837083
#
# Cost at iteration 327 = 0.17381473592809585
#
# Cost at iteration 328 = 0.17380009186432704
#
# Cost at iteration 329 = 0.17378545138617976
#
# Cost at iteration 330 = 0.17377081449276943
#
# Cost at iteration 331 = 0.17375618118321182
#
# Cost at iteration 332 = 0.17374155145662282
#
# Cost at iteration 333 = 0.17372692531211867
#
# Cost at iteration 334 = 0.17371230274881563
#
# Cost at iteration 335 = 0.17369768376583047
#
# Cost at iteration 336 = 0.17368306836227987
#
# Cost at iteration 337 = 0.173668456537281
#
# Cost at iteration 338 = 0.17365384828995103
#
# Cost at iteration 339 = 0.1736392436194076
#
# Cost at iteration 340 = 0.17362464252476834
#
# Cost at iteration 341 = 0.1736100450051513
#
# Cost at iteration 342 = 0.17359545105967453
#
# Cost at iteration 343 = 0.17358086068745646
#
# Cost at iteration 344 = 0.17356627388761578
#
# Cost at iteration 345 = 0.17355169065927128
#
# Cost at iteration 346 = 0.17353711100154204
#
# Cost at iteration 347 = 0.17352253491354738
#
# Cost at iteration 348 = 0.17350796239440675
#
# Cost at iteration 349 = 0.17349339344323994
#
# Cost at iteration 350 = 0.17347882805916687
#
# Cost at iteration 351 = 0.17346426624130773
#
# Cost at iteration 352 = 0.17344970798878298
#
# Cost at iteration 353 = 0.17343515330071316
#
# Cost at iteration 354 = 0.17342060217621913
#
# Cost at iteration 355 = 0.17340605461442204
#
# Cost at iteration 356 = 0.1733915106144431
#
# Cost at iteration 357 = 0.1733769701754039
#
# Cost at iteration 358 = 0.17336243329642612
#
# Cost at iteration 359 = 0.17334789997663175
#
# Cost at iteration 360 = 0.17333337021514297
#
# Cost at iteration 361 = 0.17331884401108216
#
# Cost at iteration 362 = 0.173304321363572
#
# Cost at iteration 363 = 0.17328980227173527
#
# Cost at iteration 364 = 0.17327528673469508
#
# Cost at iteration 365 = 0.17326077475157475
#
# Cost at iteration 366 = 0.17324626632149773
#
# Cost at iteration 367 = 0.17323176144358782
#
# Cost at iteration 368 = 0.17321726011696892
#
# Cost at iteration 369 = 0.17320276234076526
#
# Cost at iteration 370 = 0.17318826811410123
#
# Cost at iteration 371 = 0.17317377743610143
#
# Cost at iteration 372 = 0.17315929030589072
#
# Cost at iteration 373 = 0.1731448067225942
#
# Cost at iteration 374 = 0.1731303266853371
#
# Cost at iteration 375 = 0.17311585019324494
#
# Cost at iteration 376 = 0.17310137724544347
#
# Cost at iteration 377 = 0.17308690784105862
#
# Cost at iteration 378 = 0.1730724419792166
#
# Cost at iteration 379 = 0.17305797965904376
#
# Cost at iteration 380 = 0.17304352087966673
#
# Cost at iteration 381 = 0.17302906564021237
#
# Cost at iteration 382 = 0.1730146139398077
#
# Cost at iteration 383 = 0.17300016577757998
#
# Cost at iteration 384 = 0.1729857211526568
#
# Cost at iteration 385 = 0.17297128006416573
#
# Cost at iteration 386 = 0.17295684251123486
#
# Cost at iteration 387 = 0.17294240849299228
#
# Cost at iteration 388 = 0.17292797800856635
#
# Cost at iteration 389 = 0.1729135510570857
#
# Cost at iteration 390 = 0.17289912763767912
#
# Cost at iteration 391 = 0.17288470774947573
#
# Cost at iteration 392 = 0.17287029139160467
#
# Cost at iteration 393 = 0.17285587856319554
#
# Cost at iteration 394 = 0.17284146926337796
#
# Cost at iteration 395 = 0.1728270634912819
#
# Cost at iteration 396 = 0.17281266124603747
#
# Cost at iteration 397 = 0.17279826252677505
#
# Cost at iteration 398 = 0.17278386733262519
#
# Cost at iteration 399 = 0.17276947566271872
#
# Cost at iteration 400 = 0.17275508751618668
#
# Cost at iteration 401 = 0.17274070289216029
#
# Cost at iteration 402 = 0.17272632178977096
#
# Cost at iteration 403 = 0.17271194420815045
#
# Cost at iteration 404 = 0.17269757014643067
#
# Cost at iteration 405 = 0.17268319960374368
#
# Cost at iteration 406 = 0.1726688325792218
#
# Cost at iteration 407 = 0.17265446907199763
#
# Cost at iteration 408 = 0.17264010908120397
#
# Cost at iteration 409 = 0.1726257526059738
#
# Cost at iteration 410 = 0.17261139964544026
#
# Cost at iteration 411 = 0.17259705019873692
#
# Cost at iteration 412 = 0.17258270426499733
#
# Cost at iteration 413 = 0.17256836184335542
#
# Cost at iteration 414 = 0.17255402293294522
#
# Cost at iteration 415 = 0.17253968753290114
#
# Cost at iteration 416 = 0.1725253556423576
#
# Cost at iteration 417 = 0.17251102726044942
#
# Cost at iteration 418 = 0.17249670238631154
#
# Cost at iteration 419 = 0.17248238101907915
#
# Cost at iteration 420 = 0.17246806315788768
#
# Cost at iteration 421 = 0.17245374880187267
#
# Cost at iteration 422 = 0.1724394379501701
#
# Cost at iteration 423 = 0.17242513060191592
#
# Cost at iteration 424 = 0.17241082675624642
#
# Cost at iteration 425 = 0.17239652641229813
#
# Cost at iteration 426 = 0.1723822295692078
#
# Cost at iteration 427 = 0.17236793622611224
#
# Cost at iteration 428 = 0.17235364638214873
#
# Cost at iteration 429 = 0.17233936003645453
#
# Cost at iteration 430 = 0.17232507718816736
#
# Cost at iteration 431 = 0.17231079783642492
#
# Cost at iteration 432 = 0.17229652198036524
#
# Cost at iteration 433 = 0.17228224961912664
#
# Cost at iteration 434 = 0.17226798075184743
#
# Cost at iteration 435 = 0.17225371537766648
#
# Cost at iteration 436 = 0.17223945349572253
#
# Cost at iteration 437 = 0.17222519510515477
#
# Cost at iteration 438 = 0.17221094020510247
#
# Cost at iteration 439 = 0.17219668879470526
#
# Cost at iteration 440 = 0.17218244087310286
#
# Cost at iteration 441 = 0.17216819643943523
#
# Cost at iteration 442 = 0.17215395549284257
#
# Cost at iteration 443 = 0.17213971803246536
#
# Cost at iteration 444 = 0.17212548405744418
#
# Cost at iteration 445 = 0.17211125356691986
#
# Cost at iteration 446 = 0.17209702656003356
#
# Cost at iteration 447 = 0.17208280303592646
#
# Cost at iteration 448 = 0.17206858299374012
#
# Cost at iteration 449 = 0.17205436643261626
#
# Cost at iteration 450 = 0.17204015335169678
#
# Cost at iteration 451 = 0.17202594375012387
#
# Cost at iteration 452 = 0.1720117376270399
#
# Cost at iteration 453 = 0.1719975349815874
#
# Cost at iteration 454 = 0.17198333581290925
#
# Cost at iteration 455 = 0.17196914012014838
#
# Cost at iteration 456 = 0.17195494790244817
#
# Cost at iteration 457 = 0.1719407591589519
#
# Cost at iteration 458 = 0.17192657388880334
#
# Cost at iteration 459 = 0.17191239209114637
#
# Cost at iteration 460 = 0.17189821376512507
#
# Cost at iteration 461 = 0.17188403890988374
#
# Cost at iteration 462 = 0.17186986752456695
#
# Cost at iteration 463 = 0.17185569960831945
#
# Cost at iteration 464 = 0.17184153516028622
#
# Cost at iteration 465 = 0.17182737417961236
#
# Cost at iteration 466 = 0.17181321666544333
#
# Cost at iteration 467 = 0.17179906261692474
#
# Cost at iteration 468 = 0.17178491203320242
#
# Cost at iteration 469 = 0.1717707649134224
#
# Cost at iteration 470 = 0.17175662125673102
#
# Cost at iteration 471 = 0.1717424810622746
#
# Cost at iteration 472 = 0.17172834432919995
#
# Cost at iteration 473 = 0.17171421105665394
#
# Cost at iteration 474 = 0.17170008124378372
#
# Cost at iteration 475 = 0.1716859548897366
#
# Cost at iteration 476 = 0.17167183199366012
#
# Cost at iteration 477 = 0.17165771255470208
#
# Cost at iteration 478 = 0.17164359657201048
#
# Cost at iteration 479 = 0.17162948404473347
#
# Cost at iteration 480 = 0.17161537497201948
#
# Cost at iteration 481 = 0.1716012693530172
#
# Cost at iteration 482 = 0.17158716718687536
#
# Cost at iteration 483 = 0.17157306847274315
#
# Cost at iteration 484 = 0.17155897320976973
#
# Cost at iteration 485 = 0.17154488139710464
#
# Cost at iteration 486 = 0.17153079303389762
#
# Cost at iteration 487 = 0.17151670811929853
#
# Cost at iteration 488 = 0.17150262665245752
#
# Cost at iteration 489 = 0.17148854863252494
#
# Cost at iteration 490 = 0.17147447405865135
#
# Cost at iteration 491 = 0.17146040292998757
#
# Cost at iteration 492 = 0.17144633524568448
#
# Cost at iteration 493 = 0.17143227100489344
#
# Cost at iteration 494 = 0.17141821020676573
#
# Cost at iteration 495 = 0.1714041528504531
#
# Cost at iteration 496 = 0.1713900989351073
#
# Cost at iteration 497 = 0.17137604845988047
#
# Cost at iteration 498 = 0.1713620014239248
#
# Cost at iteration 499 = 0.17134795782639292
#
# Cost at iteration 500 = 0.17133391766643738
#
# Cost at iteration 501 = 0.17131988094321118
#
# Cost at iteration 502 = 0.17130584765586745
#
# Cost at iteration 503 = 0.17129181780355957
#
# Cost at iteration 504 = 0.171277791385441
#
# Cost at iteration 505 = 0.17126376840066557
#
# Cost at iteration 506 = 0.17124974884838728
#
# Cost at iteration 507 = 0.17123573272776033
#
# Cost at iteration 508 = 0.17122172003793912
#
# Cost at iteration 509 = 0.17120771077807828
#
# Cost at iteration 510 = 0.1711937049473327
#
# Cost at iteration 511 = 0.17117970254485734
#
# Cost at iteration 512 = 0.1711657035698075
#
# Cost at iteration 513 = 0.17115170802133872
#
# Cost at iteration 514 = 0.17113771589860666
#
# Cost at iteration 515 = 0.17112372720076718
#
# Cost at iteration 516 = 0.17110974192697648
#
# Cost at iteration 517 = 0.17109576007639082
#
# Cost at iteration 518 = 0.17108178164816681
#
# Cost at iteration 519 = 0.17106780664146118
#
# Cost at iteration 520 = 0.17105383505543087
#
# Cost at iteration 521 = 0.17103986688923314
#
# Cost at iteration 522 = 0.17102590214202534
#
# Cost at iteration 523 = 0.17101194081296506
#
# Cost at iteration 524 = 0.17099798290121018
#
# Cost at iteration 525 = 0.1709840284059187
#
# Cost at iteration 526 = 0.1709700773262489
#
# Cost at iteration 527 = 0.17095612966135915
#
# Cost at iteration 528 = 0.17094218541040823
#
# Cost at iteration 529 = 0.17092824457255498
#
# Cost at iteration 530 = 0.17091430714695852
#
# Cost at iteration 531 = 0.1709003731327781
#
# Cost at iteration 532 = 0.1708864425291733
#
# Cost at iteration 533 = 0.17087251533530384
#
# Cost at iteration 534 = 0.17085859155032965
#
# Cost at iteration 535 = 0.1708446711734109
#
# Cost at iteration 536 = 0.17083075420370797
#
# Cost at iteration 537 = 0.1708168406403814
#
# Cost at iteration 538 = 0.17080293048259204
#
# Cost at iteration 539 = 0.17078902372950086
#
# Cost at iteration 540 = 0.1707751203802691
#
# Cost at iteration 541 = 0.17076122043405817
#
# Cost at iteration 542 = 0.1707473238900297
#
# Cost at iteration 543 = 0.17073343074734557
#
# Cost at iteration 544 = 0.1707195410051678
#
# Cost at iteration 545 = 0.17070565466265875
#
# Cost at iteration 546 = 0.1706917717189808
#
# Cost at iteration 547 = 0.17067789217329674
#
# Cost at iteration 548 = 0.17066401602476944
#
# Cost at iteration 549 = 0.17065014327256195
#
# Cost at iteration 550 = 0.17063627391583772
#
# Cost at iteration 551 = 0.17062240795376019
#
# Cost at iteration 552 = 0.1706085453854932
#
# Cost at iteration 553 = 0.17059468621020066
#
# Cost at iteration 554 = 0.17058083042704678
#
# Cost at iteration 555 = 0.17056697803519588
#
# Cost at iteration 556 = 0.17055312903381262
#
# Cost at iteration 557 = 0.17053928342206182
#
# Cost at iteration 558 = 0.17052544119910842
#
# Cost at iteration 559 = 0.17051160236411766
#
# Cost at iteration 560 = 0.1704977669162551
#
# Cost at iteration 561 = 0.17048393485468624
#
# Cost at iteration 562 = 0.17047010617857702
#
# Cost at iteration 563 = 0.1704562808870935
#
# Cost at iteration 564 = 0.1704424589794019
#
# Cost at iteration 565 = 0.17042864045466882
#
# Cost at iteration 566 = 0.17041482531206087
#
# Cost at iteration 567 = 0.170401013550745
#
# Cost at iteration 568 = 0.1703872051698883
#
# Cost at iteration 569 = 0.17037340016865818
#
# Cost at iteration 570 = 0.1703595985462221
#
# Cost at iteration 571 = 0.1703458003017478
#
# Cost at iteration 572 = 0.17033200543440336
#
# Cost at iteration 573 = 0.17031821394335683
#
# Cost at iteration 574 = 0.17030442582777658
#
# Cost at iteration 575 = 0.17029064108683134
#
# Cost at iteration 576 = 0.17027685971968975
#
# Cost at iteration 577 = 0.17026308172552093
#
# Cost at iteration 578 = 0.17024930710349406
#
# Cost at iteration 579 = 0.17023553585277854
#
# Cost at iteration 580 = 0.17022176797254407
#
# Cost at iteration 581 = 0.17020800346196044
#
# Cost at iteration 582 = 0.17019424232019773
#
# Cost at iteration 583 = 0.17018048454642623
#
# Cost at iteration 584 = 0.17016673013981634
#
# Cost at iteration 585 = 0.1701529790995389
#
# Cost at iteration 586 = 0.17013923142476461
#
# Cost at iteration 587 = 0.1701254871146647
#
# Cost at iteration 588 = 0.1701117461684104
#
# Cost at iteration 589 = 0.1700980085851733
#
# Cost at iteration 590 = 0.17008427436412513
#
# Cost at iteration 591 = 0.17007054350443776
#
# Cost at iteration 592 = 0.17005681600528338
#
# Cost at iteration 593 = 0.1700430918658344
#
# Cost at iteration 594 = 0.1700293710852633
#
# Cost at iteration 595 = 0.17001565366274288
#
# Cost at iteration 596 = 0.1700019395974461
#
# Cost at iteration 597 = 0.16998822888854623
#
# Cost at iteration 598 = 0.16997452153521658
#
# Cost at iteration 599 = 0.1699608175366308
#
# Cost at iteration 600 = 0.16994711689196265
#
# Cost at iteration 601 = 0.16993341960038624
#
# Cost at iteration 602 = 0.16991972566107574
#
# Cost at iteration 603 = 0.16990603507320562
#
# Cost at iteration 604 = 0.16989234783595053
#
# Cost at iteration 605 = 0.16987866394848528
#
# Cost at iteration 606 = 0.16986498340998496
#
# Cost at iteration 607 = 0.1698513062196249
#
# Cost at iteration 608 = 0.16983763237658048
#
# Cost at iteration 609 = 0.1698239618800275
#
# Cost at iteration 610 = 0.1698102947291417
#
# Cost at iteration 611 = 0.16979663092309932
#
# Cost at iteration 612 = 0.16978297046107663
#
# Cost at iteration 613 = 0.16976931334225012
#
# Cost at iteration 614 = 0.16975565956579652
#
# Cost at iteration 615 = 0.16974200913089282
#
# Cost at iteration 616 = 0.1697283620367161
#
# Cost at iteration 617 = 0.16971471828244375
#
# Cost at iteration 618 = 0.16970107786725327
#
# Cost at iteration 619 = 0.16968744079032247
#
# Cost at iteration 620 = 0.16967380705082932
#
# Cost at iteration 621 = 0.16966017664795197
#
# Cost at iteration 622 = 0.16964654958086883
#
# Cost at iteration 623 = 0.16963292584875847
#
# Cost at iteration 624 = 0.16961930545079967
#
# Cost at iteration 625 = 0.16960568838617152
#
# Cost at iteration 626 = 0.16959207465405313
#
# Cost at iteration 627 = 0.16957846425362397
#
# Cost at iteration 628 = 0.16956485718406367
#
# Cost at iteration 629 = 0.16955125344455202
#
# Cost at iteration 630 = 0.16953765303426913
#
# Cost at iteration 631 = 0.16952405595239514
#
# Cost at iteration 632 = 0.1695104621981106
#
# Cost at iteration 633 = 0.16949687177059616
#
# Cost at iteration 634 = 0.16948328466903265
#
# Cost at iteration 635 = 0.16946970089260113
#
# Cost at iteration 636 = 0.1694561204404829
#
# Cost at iteration 637 = 0.16944254331185946
#
# Cost at iteration 638 = 0.16942896950591246
#
# Cost at iteration 639 = 0.1694153990218238
#
# Cost at iteration 640 = 0.16940183185877564
#
# Cost at iteration 641 = 0.16938826801595025
#
# Cost at iteration 642 = 0.16937470749253009
#
# Cost at iteration 643 = 0.169361150287698
#
# Cost at iteration 644 = 0.16934759640063676
#
# Cost at iteration 645 = 0.16933404583052963
#
# Cost at iteration 646 = 0.16932049857655992
#
# Cost at iteration 647 = 0.1693069546379111
#
# Cost at iteration 648 = 0.16929341401376702
#
# Cost at iteration 649 = 0.16927987670331154
#
# Cost at iteration 650 = 0.16926634270572888
#
# Cost at iteration 651 = 0.16925281202020342
#
# Cost at iteration 652 = 0.16923928464591967
#
# Cost at iteration 653 = 0.16922576058206246
#
# Cost at iteration 654 = 0.16921223982781675
#
# Cost at iteration 655 = 0.16919872238236774
#
# Cost at iteration 656 = 0.1691852082449008
#
# Cost at iteration 657 = 0.16917169741460153
#
# Cost at iteration 658 = 0.16915818989065576
#
# Cost at iteration 659 = 0.16914468567224944
#
# Cost at iteration 660 = 0.16913118475856886
#
# Cost at iteration 661 = 0.1691176871488004
#
# Cost at iteration 662 = 0.16910419284213069
#
# Cost at iteration 663 = 0.16909070183774652
#
# Cost at iteration 664 = 0.16907721413483498
#
# Cost at iteration 665 = 0.16906372973258327
#
# Cost at iteration 666 = 0.1690502486301788
#
# Cost at iteration 667 = 0.16903677082680935
#
# Cost at iteration 668 = 0.1690232963216626
#
# Cost at iteration 669 = 0.16900982511392673
#
# Cost at iteration 670 = 0.1689963572027899
#
# Cost at iteration 671 = 0.1689828925874407
#
# Cost at iteration 672 = 0.1689694312670677
#
# Cost at iteration 673 = 0.16895597324085979
#
# Cost at iteration 674 = 0.16894251850800607
#
# Cost at iteration 675 = 0.1689290670676958
#
# Cost at iteration 676 = 0.16891561891911847
#
# Cost at iteration 677 = 0.16890217406146377
#
# Cost at iteration 678 = 0.16888873249392164
#
# Cost at iteration 679 = 0.16887529421568212
#
# Cost at iteration 680 = 0.1688618592259355
#
# Cost at iteration 681 = 0.16884842752387236
#
# Cost at iteration 682 = 0.1688349991086833
#
# Cost at iteration 683 = 0.1688215739795593
#
# Cost at iteration 684 = 0.16880815213569153
#
# Cost at iteration 685 = 0.1687947335762712
#
# Cost at iteration 686 = 0.1687813183004899
#
# Cost at iteration 687 = 0.16876790630753935
#
# Cost at iteration 688 = 0.16875449759661146
#
# Cost at iteration 689 = 0.1687410921668984
#
# Cost at iteration 690 = 0.16872769001759244
#
# Cost at iteration 691 = 0.16871429114788622
#
# Cost at iteration 692 = 0.1687008955569724
#
# Cost at iteration 693 = 0.168687503244044
#
# Cost at iteration 694 = 0.1686741142082941
#
# Cost at iteration 695 = 0.16866072844891608
#
# Cost at iteration 696 = 0.1686473459651035
#
# Cost at iteration 697 = 0.1686339667560501
#
# Cost at iteration 698 = 0.16862059082094988
#
# Cost at iteration 699 = 0.168607218158997
#
# Cost at iteration 700 = 0.16859384876938582
#
# Cost at iteration 701 = 0.1685804826513109
#
# Cost at iteration 702 = 0.16856711980396702
#
# Cost at iteration 703 = 0.16855376022654917
#
# Cost at iteration 704 = 0.1685404039182525
#
# Cost at iteration 705 = 0.1685270508782724
#
# Cost at iteration 706 = 0.1685137011058045
#
# Cost at iteration 707 = 0.16850035460004453
#
# Cost at iteration 708 = 0.1684870113601885
#
# Cost at iteration 709 = 0.16847367138543262
#
# Cost at iteration 710 = 0.16846033467497323
#
# Cost at iteration 711 = 0.168447001228007
#
# Cost at iteration 712 = 0.16843367104373067
#
# Cost at iteration 713 = 0.16842034412134124
#
# Cost at iteration 714 = 0.16840702046003597
#
# Cost at iteration 715 = 0.1683937000590122
#
# Cost at iteration 716 = 0.16838038291746757
#
# Cost at iteration 717 = 0.16836706903459986
#
# Cost at iteration 718 = 0.16835375840960712
#
# Cost at iteration 719 = 0.16834045104168757
#
# Cost at iteration 720 = 0.16832714693003958
#
# Cost at iteration 721 = 0.16831384607386177
#
# Cost at iteration 722 = 0.16830054847235298
#
# Cost at iteration 723 = 0.16828725412471224
#
# Cost at iteration 724 = 0.16827396303013872
#
# Cost at iteration 725 = 0.1682606751878319
#
# Cost at iteration 726 = 0.16824739059699134
#
# Cost at iteration 727 = 0.16823410925681692
#
# Cost at iteration 728 = 0.16822083116650863
#
# Cost at iteration 729 = 0.1682075563252667
#
# Cost at iteration 730 = 0.16819428473229164
#
# Cost at iteration 731 = 0.16818101638678393
#
# Cost at iteration 732 = 0.16816775128794453
#
# Cost at iteration 733 = 0.1681544894349744
#
# Cost at iteration 734 = 0.1681412308270748
#
# Cost at iteration 735 = 0.16812797546344715
#
# Cost at iteration 736 = 0.1681147233432931
#
# Cost at iteration 737 = 0.1681014744658145
#
# Cost at iteration 738 = 0.16808822883021335
#
# Cost at iteration 739 = 0.1680749864356919
#
# Cost at iteration 740 = 0.16806174728145257
#
# Cost at iteration 741 = 0.16804851136669807
#
# Cost at iteration 742 = 0.16803527869063115
#
# Cost at iteration 743 = 0.16802204925245492
#
# Cost at iteration 744 = 0.16800882305137255
#
# Cost at iteration 745 = 0.1679956000865875
#
# Cost at iteration 746 = 0.16798238035730345
#
# Cost at iteration 747 = 0.16796916386272423
#
# Cost at iteration 748 = 0.16795595060205387
#
# Cost at iteration 749 = 0.1679427405744966
#
# Cost at iteration 750 = 0.16792953377925685
#
# Cost at iteration 751 = 0.1679163302155393
#
# Cost at iteration 752 = 0.16790312988254882
#
# Cost at iteration 753 = 0.16788993277949035
#
# Cost at iteration 754 = 0.1678767389055692
#
# Cost at iteration 755 = 0.1678635482599908
#
# Cost at iteration 756 = 0.1678503608419608
#
# Cost at iteration 757 = 0.16783717665068507
#
# Cost at iteration 758 = 0.16782399568536954
#
# Cost at iteration 759 = 0.16781081794522057
#
# Cost at iteration 760 = 0.16779764342944456
#
# Cost at iteration 761 = 0.16778447213724812
#
# Cost at iteration 762 = 0.16777130406783813
#
# Cost at iteration 763 = 0.1677581392204216
#
# Cost at iteration 764 = 0.16774497759420576
#
# Cost at iteration 765 = 0.1677318191883981
#
# Cost at iteration 766 = 0.16771866400220622
#
# Cost at iteration 767 = 0.16770551203483794
#
# Cost at iteration 768 = 0.16769236328550136
#
# Cost at iteration 769 = 0.1676792177534046
#
# Cost at iteration 770 = 0.16766607543775622
#
# Cost at iteration 771 = 0.1676529363377648
#
# Cost at iteration 772 = 0.16763980045263913
#
# Cost at iteration 773 = 0.16762666778158833
#
# Cost at iteration 774 = 0.1676135383238215
#
# Cost at iteration 775 = 0.1676004120785482
#
# Cost at iteration 776 = 0.16758728904497797
#
# Cost at iteration 777 = 0.16757416922232068
#
# Cost at iteration 778 = 0.16756105260978635
#
# Cost at iteration 779 = 0.1675479392065852
#
# Cost at iteration 780 = 0.16753482901192765
#
# Cost at iteration 781 = 0.16752172202502427
#
# Cost at iteration 782 = 0.16750861824508595
#
# Cost at iteration 783 = 0.16749551767132367
#
# Cost at iteration 784 = 0.1674824203029487
#
# Cost at iteration 785 = 0.16746932613917234
#
# Cost at iteration 786 = 0.16745623517920635
#
# Cost at iteration 787 = 0.1674431474222624
#
# Cost at iteration 788 = 0.16743006286755258
#
# Cost at iteration 789 = 0.16741698151428908
#
# Cost at iteration 790 = 0.1674039033616843
#
# Cost at iteration 791 = 0.1673908284089508
#
# Cost at iteration 792 = 0.16737775665530147
#
# Cost at iteration 793 = 0.16736468809994923
#
# Cost at iteration 794 = 0.16735162274210733
#
# Cost at iteration 795 = 0.16733856058098912
#
# Cost at iteration 796 = 0.16732550161580823
#
# Cost at iteration 797 = 0.1673124458457784
#
# Cost at iteration 798 = 0.16729939327011364
#
# Cost at iteration 799 = 0.16728634388802816
#
# Cost at iteration 800 = 0.1672732976987363
#
# Cost at iteration 801 = 0.1672602547014527
#
# Cost at iteration 802 = 0.16724721489539204
#
# Cost at iteration 803 = 0.16723417827976939
#
# Cost at iteration 804 = 0.16722114485379985
#
# Cost at iteration 805 = 0.16720811461669885
#
# Cost at iteration 806 = 0.16719508756768192
#
# Cost at iteration 807 = 0.16718206370596483
#
# Cost at iteration 808 = 0.16716904303076352
#
# Cost at iteration 809 = 0.1671560255412942
#
# Cost at iteration 810 = 0.1671430112367731
#
# Cost at iteration 811 = 0.1671300001164169
#
# Cost at iteration 812 = 0.16711699217944234
#
# Cost at iteration 813 = 0.1671039874250663
#
# Cost at iteration 814 = 0.16709098585250595
#
# Cost at iteration 815 = 0.16707798746097866
#
# Cost at iteration 816 = 0.1670649922497019
#
# Cost at iteration 817 = 0.16705200021789346
#
# Cost at iteration 818 = 0.16703901136477123
#
# Cost at iteration 819 = 0.16702602568955335
#
# Cost at iteration 820 = 0.1670130431914581
#
# Cost at iteration 821 = 0.1670000638697041
#
# Cost at iteration 822 = 0.16698708772350995
#
# Cost at iteration 823 = 0.16697411475209462
#
# Cost at iteration 824 = 0.1669611449546772
#
# Cost at iteration 825 = 0.166948178330477
#
# Cost at iteration 826 = 0.16693521487871352
#
# Cost at iteration 827 = 0.16692225459860646
#
# Cost at iteration 828 = 0.1669092974893757
#
# Cost at iteration 829 = 0.1668963435502413
#
# Cost at iteration 830 = 0.16688339278042358
#
# Cost at iteration 831 = 0.16687044517914298
#
# Cost at iteration 832 = 0.16685750074562025
#
# Cost at iteration 833 = 0.1668445594790762
#
# Cost at iteration 834 = 0.16683162137873186
#
# Cost at iteration 835 = 0.1668186864438086
#
# Cost at iteration 836 = 0.1668057546735278
#
# Cost at iteration 837 = 0.16679282606711113
#
# Cost at iteration 838 = 0.1667799006237804
#
# Cost at iteration 839 = 0.16676697834275772
#
# Cost at iteration 840 = 0.1667540592232653
#
# Cost at iteration 841 = 0.16674114326452558
#
# Cost at iteration 842 = 0.16672823046576118
#
# Cost at iteration 843 = 0.16671532082619492
#
# Cost at iteration 844 = 0.16670241434504982
#
# Cost at iteration 845 = 0.1666895110215491
#
# Cost at iteration 846 = 0.16667661085491622
#
# Cost at iteration 847 = 0.16666371384437473
#
# Cost at iteration 848 = 0.16665081998914838
#
# Cost at iteration 849 = 0.16663792928846127
#
# Cost at iteration 850 = 0.16662504174153756
#
# Cost at iteration 851 = 0.16661215734760157
#
# Cost at iteration 852 = 0.16659927610587796
#
# Cost at iteration 853 = 0.1665863980155915
#
# Cost at iteration 854 = 0.16657352307596712
#
# Cost at iteration 855 = 0.16656065128623002
#
# Cost at iteration 856 = 0.1665477826456055
#
# Cost at iteration 857 = 0.16653491715331917
#
# Cost at iteration 858 = 0.16652205480859675
#
# Cost at iteration 859 = 0.1665091956106642
#
# Cost at iteration 860 = 0.16649633955874768
#
# Cost at iteration 861 = 0.16648348665207344
#
# Cost at iteration 862 = 0.16647063688986807
#
# Cost at iteration 863 = 0.1664577902713583
#
# Cost at iteration 864 = 0.16644494679577101
#
# Cost at iteration 865 = 0.1664321064623333
#
# Cost at iteration 866 = 0.1664192692702725
#
# Cost at iteration 867 = 0.1664064352188161
#
# Cost at iteration 868 = 0.16639360430719177
#
# Cost at iteration 869 = 0.1663807765346274
#
# Cost at iteration 870 = 0.1663679519003511
#
# Cost at iteration 871 = 0.16635513040359112
#
# Cost at iteration 872 = 0.1663423120435759
#
# Cost at iteration 873 = 0.16632949681953418
#
# Cost at iteration 874 = 0.16631668473069466
#
# Cost at iteration 875 = 0.16630387577628655
#
# Cost at iteration 876 = 0.166291069955539
#
# Cost at iteration 877 = 0.16627826726768147
#
# Cost at iteration 878 = 0.16626546771194356
#
# Cost at iteration 879 = 0.16625267128755514
#
# Cost at iteration 880 = 0.16623987799374618
#
# Cost at iteration 881 = 0.16622708782974693
#
# Cost at iteration 882 = 0.16621430079478772
#
# Cost at iteration 883 = 0.1662015168880992
#
# Cost at iteration 884 = 0.16618873610891216
#
# Cost at iteration 885 = 0.16617595845645752
#
# Cost at iteration 886 = 0.16616318392996654
#
# Cost at iteration 887 = 0.16615041252867052
#
# Cost at iteration 888 = 0.16613764425180103
#
# Cost at iteration 889 = 0.16612487909858983
#
# Cost at iteration 890 = 0.16611211706826892
#
# Cost at iteration 891 = 0.16609935816007032
#
# Cost at iteration 892 = 0.16608660237322645
#
# Cost at iteration 893 = 0.16607384970696978
#
# Cost at iteration 894 = 0.16606110016053308
#
# Cost at iteration 895 = 0.1660483537331492
#
# Cost at iteration 896 = 0.1660356104240513
#
# Cost at iteration 897 = 0.16602287023247259
#
# Cost at iteration 898 = 0.16601013315764665
#
# Cost at iteration 899 = 0.16599739919880716
#
# Cost at iteration 900 = 0.16598466835518785
#
# Cost at iteration 901 = 0.16597194062602294
#
# Cost at iteration 902 = 0.16595921601054658
#
# Cost at iteration 903 = 0.1659464945079933
#
# Cost at iteration 904 = 0.16593377611759766
#
# Cost at iteration 905 = 0.16592106083859454
#
# Cost at iteration 906 = 0.16590834867021897
#
# Cost at iteration 907 = 0.1658956396117061
#
# Cost at iteration 908 = 0.16588293366229145
#
# Cost at iteration 909 = 0.16587023082121052
#
# Cost at iteration 910 = 0.16585753108769913
#
# Cost at iteration 911 = 0.16584483446099327
#
# Cost at iteration 912 = 0.1658321409403291
#
# Cost at iteration 913 = 0.165819450524943
#
# Cost at iteration 914 = 0.16580676321407153
#
# Cost at iteration 915 = 0.16579407900695148
#
# Cost at iteration 916 = 0.16578139790281968
#
# Cost at iteration 917 = 0.16576871990091332
#
# Cost at iteration 918 = 0.16575604500046978
#
# Cost at iteration 919 = 0.1657433732007265
#
# Cost at iteration 920 = 0.1657307045009212
#
# Cost at iteration 921 = 0.1657180389002918
#
# Cost at iteration 922 = 0.1657053763980764
#
# Cost at iteration 923 = 0.16569271699351323
#
# Cost at iteration 924 = 0.16568006068584076
#
# Cost at iteration 925 = 0.16566740747429773
#
# Cost at iteration 926 = 0.16565475735812293
#
# Cost at iteration 927 = 0.16564211033655543
#
# Cost at iteration 928 = 0.1656294664088344
#
# Cost at iteration 929 = 0.16561682557419935
#
# Cost at iteration 930 = 0.16560418783188988
#
# Cost at iteration 931 = 0.1655915531811458
#
# Cost at iteration 932 = 0.16557892162120702
#
# Cost at iteration 933 = 0.16556629315131385
#
# Cost at iteration 934 = 0.16555366777070663
#
# Cost at iteration 935 = 0.1655410454786259
#
# Cost at iteration 936 = 0.16552842627431238
#
# Cost at iteration 937 = 0.16551581015700717
#
# Cost at iteration 938 = 0.16550319712595127
#
# Cost at iteration 939 = 0.1654905871803861
#
# Cost at iteration 940 = 0.16547798031955313
#
# Cost at iteration 941 = 0.16546537654269408
#
# Cost at iteration 942 = 0.16545277584905088
#
# Cost at iteration 943 = 0.16544017823786558
#
# Cost at iteration 944 = 0.1654275837083805
#
# Cost at iteration 945 = 0.1654149922598381
#
# Cost at iteration 946 = 0.16540240389148106
#
# Cost at iteration 947 = 0.1653898186025522
#
# Cost at iteration 948 = 0.16537723639229454
#
# Cost at iteration 949 = 0.16536465725995142
#
# Cost at iteration 950 = 0.16535208120476613
#
# Cost at iteration 951 = 0.16533950822598242
#
# Cost at iteration 952 = 0.16532693832284398
#
# Cost at iteration 953 = 0.16531437149459483
#
# Cost at iteration 954 = 0.16530180774047915
#
# Cost at iteration 955 = 0.16528924705974132
#
# Cost at iteration 956 = 0.16527668945162594
#
# Cost at iteration 957 = 0.16526413491537773
#
# Cost at iteration 958 = 0.16525158345024155
#
# Cost at iteration 959 = 0.16523903505546267
#
# Cost at iteration 960 = 0.1652264897302863
#
# Cost at iteration 961 = 0.165213947473958
#
# Cost at iteration 962 = 0.1652014082857234
#
# Cost at iteration 963 = 0.16518887216482853
#
# Cost at iteration 964 = 0.16517633911051932
#
# Cost at iteration 965 = 0.1651638091220421
#
# Cost at iteration 966 = 0.16515128219864328
#
# Cost at iteration 967 = 0.16513875833956956
#
# Cost at iteration 968 = 0.16512623754406772
#
# Cost at iteration 969 = 0.16511371981138478
#
# Cost at iteration 970 = 0.16510120514076798
#
# Cost at iteration 971 = 0.16508869353146474
#
# Cost at iteration 972 = 0.16507618498272258
#
# Cost at iteration 973 = 0.16506367949378933
#
# Cost at iteration 974 = 0.16505117706391292
#
# Cost at iteration 975 = 0.16503867769234148
#
# Cost at iteration 976 = 0.1650261813783234
#
# Cost at iteration 977 = 0.16501368812110717
#
# Cost at iteration 978 = 0.16500119791994156
#
# Cost at iteration 979 = 0.1649887107740754
#
# Cost at iteration 980 = 0.16497622668275785
#
# Cost at iteration 981 = 0.16496374564523816
#
# Cost at iteration 982 = 0.16495126766076582
#
# Cost at iteration 983 = 0.16493879272859047
#
# Cost at iteration 984 = 0.1649263208479619
#
# Cost at iteration 985 = 0.1649138520181303
#
# Cost at iteration 986 = 0.16490138623834572
#
# Cost at iteration 987 = 0.1648889235078587
#
# Cost at iteration 988 = 0.16487646382591975
#
# Cost at iteration 989 = 0.1648640071917797
#
# Cost at iteration 990 = 0.16485155360468953
#
# Cost at iteration 991 = 0.16483910306390037
#
# Cost at iteration 992 = 0.16482665556866358
#
# Cost at iteration 993 = 0.16481421111823072
#
# Cost at iteration 994 = 0.16480176971185354
#
# Cost at iteration 995 = 0.16478933134878387
#
# Cost at iteration 996 = 0.16477689602827386
#
# Cost at iteration 997 = 0.16476446374957576
#
# Cost at iteration 998 = 0.16475203451194212
#
# Cost at iteration 999 = 0.1647396083146255
#
# Cost at iteration 1000 = 0.16472718515687887

# %%
print('Root Mean Squared Error on Training Data = ' + str(train_acc))
print('Root Mean Squared Error on Test Data = ' + str(test_acc))
# Out:
# Root Mean Squared Error on Training Data = 0.3294295300759103
# Root Mean Squared Error on Test Data = 0.31624318385953
